# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1064.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input())
b = float(input())
c = float(input())
d = float(input())
e = float(input())
f = float(input())

s = 0
m = 0

if a > 0:
  s = s + 1
  m = m + a

if b > 0:
  s = s + 1
  m = m + b

if c > 0:
  s = s + 1
  m = m + c

if d > 0:
  s = s + 1
  m = m + d

if e > 0:
  s = s + 1
  m = m + e

if f > 0:
  s = s + 1
  m = m + f

media = m / s
print('{} valores positivos'.format(s))
print('{:.1f}'.format(media))
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 6 valores positivos
# 2.0
