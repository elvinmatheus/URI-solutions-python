# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1044.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = input().split()
a = int(a)
b = int(b)

if a % b == 0 or b % a == 0:
  print('Sao Multiplos')
else:
  print('Nao sao Multiplos')
# Out:
# 6 25
# Nao sao Multiplos
