# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1049.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = input()
y = input()
z = input()

if x == 'vertebrado':
  if y == 'ave':
    if z == 'carnivoro':
      a = 'aguia'
    else:
      a = 'pomba'
  elif z == 'onivoro':
    a = 'homem'
  else:
    a = 'vaca'
else:
  if y == 'inseto':
    if z == 'hematofago':
      a = 'pulga'
    else:
      a = 'lagarta'
  elif z == 'hematofago':
    a = 'sanguessuga'
  else:
    a = 'minhoca'
     
print(a)
# Out:
# invertebrado
# anelideo
# onivoro
# minhoca
