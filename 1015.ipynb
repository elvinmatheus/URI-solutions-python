# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions/blob/main/1015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1, y1 = [float(x) for x in input().split()]
x2, y2 = [float(x) for x in input().split()]
d = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5
print('%.4f' % d)
# Out:
# -2.5 0.4
# 12.1 7.3
# 16.1484
