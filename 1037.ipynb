# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions/blob/main/1037.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input())

if a < 0 or a > 100:
  print('Fora de intervalo')
if 0 <= a <= 25:
  print('Intervalo [0,25]')
if 25 < a <= 50:
  print('Intervalo (25,50]')
if 50 < a <= 75:
  print('Intervalo (50,75]')
if 75 < a <= 100:
  print('Intervalo (75,100]')
# Out:
# 101
# Fora de intervalo
