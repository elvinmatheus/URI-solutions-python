# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1051.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
renda = float(input())

if renda <= 2000.00:
  print('Isento')

if 2000.01 <= renda <= 3000.00:
  i = (renda - 2000.00) * 0.08

if 3000.01 <= renda <= 4500.00:
  i = (renda - 3000.00) * 0.18 + (0.08 * 1000.00)

if renda > 4500.00:
  i = (renda - 4500.00) * 0.28 + (0.08 * 1000.00) + (0.18 * 1500.00)

if renda > 2000.00:
  print('R$ %.2f' % i)
# Out:
# 1701.12
# Isento
