# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1038.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = input().split()
a = int(a)
b = int(b)
total = float()

if a == 1:
  total = 4.00 * b
if a == 2:
  total = 4.50 * b
if a == 3:
  total = 5.00 * b
if a == 4:
  total = 2.00 * b
if a == 5:
  total = 1.50 * b

print('Total: R$ %.2f' %total)
# Out:
# 3 2
# Total: R$ 10.00
