# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1174.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v = list(range(100))

for i in range(100):
  n = float(input())
  v[i] = n
  if n <= 10:
    print('A[{}] = {}'.format(i, v[i]))
# Out:
# 3
# A[0] = 3.0
# 11
# -6
# A[2] = -6.0
