# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions/blob/main/1011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
raio = float(input())
pi = 3.14159
volume = (4/3) * pi * raio ** 3
print('VOLUME = %.3f' % volume)
# Out:
# 3
# VOLUME = 113.097
