# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1043.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b, c = input().split()
a = float(a)
b = float(b)
c = float(c)

if a + b > c and a + c > b and b + c > a:
  p = a + b + c
  print('Perimetro = %.1f' %p)
else:
  area_trapezio = ((a + b) * c) / 2
  print('Area = %.1f' %area_trapezio)
# Out:
# 6.0 4.0 2.1
# Perimetro = 12.1
