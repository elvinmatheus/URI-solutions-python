# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions/blob/main/1013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b, c = [int(x) for x in input().split()] ## nesse momento ainda não era permitido laços
maiorAB = int((a + b + abs(a - b))/2)
maiorABC = int((maiorAB + c + abs(maiorAB - c))/2)
print(maiorABC, 'eh o maior')
# Out:
# 5 7 98
# 98 eh o maior
