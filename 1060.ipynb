# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1060.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
for x in range(1,7):
  a = float(input())
  if a > 0:
    i = i + 1

print('{} valores positivos'.format(i))
# Out:
# Entre um valor numérico: 7
# Entre um valor numérico: -5
# Entre um valor numérico: 6
# Entre um valor numérico: -3.4
# Entre um valor numérico: 4.6
# Entre um valor numérico: 12
# 4 valores positivos
