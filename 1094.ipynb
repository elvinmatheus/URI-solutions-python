# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1094.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = int(input())
total = 0
coelho = 0
rato = 0
sapo = 0

while N > 0:
  x = input().split()
  quantia = int(x[0])
  tipo = str(x[1])
  if tipo == 'C':
      coelho = coelho + quantia
  if tipo == 'R':
      rato = rato + quantia
  if tipo == 'S':
      sapo = sapo + quantia
  
  total = total + quantia
  N = N - 1

print('Total: {} cobaias'.format(total))
print('Total de coelhos: {}'.format(coelho))
print('Total de ratos: {}'.format(rato))
print('Total de sapos: {}'.format(sapo))
print('Percentual de coelhos: {:.2f} %'.format((coelho / total * 100)))
print('Percentual de ratos: {:.2f} %'.format((rato / total * 100)))
print('Percentual de sapos: {:.2f} %'.format((sapo / total * 100)))
# Out:
# Entre com a quantidade de experimentos no laboratório: 10
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 10 C
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 6 R
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 15 S
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 5 C
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 14 R
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 9 C
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 6 R
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 8 S
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 5 C
# Entre com a quantidade de cobaias utilizadas e sua respectiva inicial: 14 R
# Total: 92 cobaias
# Total de coelhos: 29
# Total de ratos: 40
# Total de sapos: 23
# Percentual de coelhos: 31.52 %
# Percentual de ratos: 43.48 %
# Percentual de sapos: 25.00 %
