# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions/blob/main/1006test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input())
b = float(input())
c = float(input())
m = (a * 2 + b * 3 + c * 5)/(2 + 3 + 5)
print('MEDIA = %.1f' % m)
# Out:
# 5
# 6
# 7
# MEDIA = 6.3
