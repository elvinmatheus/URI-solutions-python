# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
I = 1
J = 60

while J >= 0:
  print('I={} J={}'.format(I, J))
  J = J - 5
  I = I + 3
# Out:
# I=1 J=60
# I=4 J=55
# I=7 J=50
# I=10 J=45
# I=13 J=40
# I=16 J=35
# I=19 J=30
# I=22 J=25
# I=25 J=20
# I=28 J=15
# I=31 J=10
# I=34 J=5
# I=37 J=0
