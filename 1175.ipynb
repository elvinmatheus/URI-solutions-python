# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1175.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = list(range(20))

for i in range(20):
  N[i] = int(input())

i = 19
for j in range(20):
  print('N[{}] = {}'.format(j, N[i])) 
  i = i - 1
# Out:
# 1
# 2
# 3
# 4
# 5
# N[0] = 5
# N[1] = 4
# N[2] = 3
# N[3] = 2
# N[4] = 1
