# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1096.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
I = 1
J = 7

while I < 10:
  while J >= 5:
    print('I={} J={}'.format(I, J))
    J = J - 1
  J = 7
  I = I + 2
# Out:
# I=1 J=7
# I=1 J=6
# I=1 J=5
# I=3 J=7
# I=3 J=6
# I=3 J=5
# I=5 J=7
# I=5 J=6
# I=5 J=5
# I=7 J=7
# I=7 J=6
# I=7 J=5
# I=9 J=7
# I=9 J=6
# I=9 J=5
