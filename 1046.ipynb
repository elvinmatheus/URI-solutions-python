# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1046.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi, hf = input().split()
hi = int(hi)
hf = int(hf)

if hi < hf:
    t = hf - hi
else:
    t = (24 - hi) + hf
print('O JOGO DUROU {} HORA(S)'.format(t))
# Out:
# 16 2
# O JOGO DUROU 10 HORA(S)
