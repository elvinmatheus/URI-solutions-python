# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinmatheus/URI-solutions-python/blob/main/1080v.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v = list(range(100))
pos = 0
maior = 0

for i in range(100):
  v[i] = int(input())
  if v[i] > maior:
    maior = v[i]
    posicao = i + 1
  
print(maior)
print(posicao)
# Out:
# 2
# 3
# 44
# 5
# 6
# 44
# 3
